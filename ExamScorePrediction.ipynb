# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
from matplotlib import pyplot as plt

# %%
# importing the dataset
dataset = pd.read_csv('Exam_Score_Prediction.csv')
dataset
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 0               1   17    male  diploma         2.78              92.9
# 1               2   23   other      bca         3.37              64.8
# 2               3   22    male     b.sc         7.88              76.8
# 3               4   20   other  diploma         0.67              48.4
# 4               5   20  female  diploma         0.89              71.6
# ...           ...  ...     ...      ...          ...               ...
# 19995       19997   18   other      bba         6.50              71.3
# 19996       19998   18    male    b.com         3.71              41.6
# 19997       19999   19   other  diploma         7.88              68.2
# 19998       20000   19    male      bba         4.60              76.3
# 19999       20001   20    male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality   study_method  \
# ...

# %%
head = dataset.head(10)
head
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
# 5           6   23    male   b.tech         3.48              65.4
# 6           7   17  female   b.tech         1.35              69.0
# 7           8   22    male     b.sc         5.48              51.1
# 8           9   18   other      bca         2.89              92.0
# 9          10   17    male      bba         6.77              44.8
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4          poor       coaching             low
# ...

# %%
tail = dataset.tail(10)
tail
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 19990       19992   24  female   b.tech         3.40              66.3
# 19991       19993   20   other      bca         2.94              90.3
# 19992       19994   17    male    b.com         5.74              81.4
# 19993       19995   19  female       ba         3.28              73.3
# 19994       19996   22   other  diploma         3.04              80.7
# 19995       19997   18   other      bba         6.50              71.3
# 19996       19998   18    male    b.com         3.71              41.6
# 19997       19999   19   other  diploma         7.88              68.2
# 19998       20000   19    male      bba         4.60              76.3
# 19999       20001   20    male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality   study_method  \
# 19990             yes          8.8          poor    group study
# ...

# %%
# Checking the column name
dataset.columns
# Out:
# Index(['student_id', 'age', 'gender', 'course', 'study_hours',
#        'class_attendance', 'internet_access', 'sleep_hours', 'sleep_quality',
#        'study_method', 'facility_rating', 'exam_difficulty', 'exam_score'],
#       dtype='object')

# %%
# Checking the information of dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        20000 non-null  int64
#  1   age               20000 non-null  int64
#  2   gender            20000 non-null  object
#  3   course            20000 non-null  object
#  4   study_hours       20000 non-null  float64
#  5   class_attendance  20000 non-null  float64
#  6   internet_access   20000 non-null  object
#  7   sleep_hours       20000 non-null  float64
#  8   sleep_quality     20000 non-null  object
#  9   study_method      20000 non-null  object
#  10  facility_rating   20000 non-null  object
#  11  exam_difficulty   20000 non-null  object
#  12  exam_score        20000 non-null  float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 2.0+ MB

# %%
# Checking the shape of the dataset
dataset.shape
# Out:
# (20000, 13)

# %%
# statistical summary of the dataset
dataset.describe()
# Out:
#          student_id           age   study_hours  class_attendance  \
# count  20000.000000  20000.000000  20000.000000      20000.000000
# mean   10000.504600     20.473300      4.007604         70.017365
# std     5773.654959      2.284458      2.308313         17.282262
# min        1.000000     17.000000      0.080000         40.600000
# 25%     5000.750000     18.000000      2.000000         55.100000
# 50%    10000.500000     20.000000      4.040000         69.900000
# 75%    15000.250000     22.000000      6.000000         85.000000
# max    20001.000000     24.000000      7.910000         99.400000
#
#        sleep_hours    exam_score
# count  20000.00000  20000.000000
# mean       7.00856     62.513225
# std        1.73209     18.908491
# min        4.10000     19.599000
# 25%        5.50000     48.800000
# 50%        7.00000     62.600000
# 75%        8.50000     76.300000
# max        9.90000    100.000000

# %%
# Checking whether the dataset has missing value or not
dataset.isnull().sum()
# Out:
# student_id          0
# age                 0
# gender              0
# course              0
# study_hours         0
# class_attendance    0
# internet_access     0
# sleep_hours         0
# sleep_quality       0
# study_method        0
# facility_rating     0
# exam_difficulty     0
# exam_score          0
# dtype: int64

# %%
# Checking some unique values
dataset['gender'].unique()
# Out:
# array(['male', 'other', 'female'], dtype=object)

# %%
dataset['course'].unique()
# Out:
# array(['diploma', 'bca', 'b.sc', 'b.tech', 'bba', 'ba', 'b.com'],
#       dtype=object)

# %%
dataset['internet_access'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
dataset['sleep_quality'].unique()
# Out:
# array(['poor', 'average', 'good'], dtype=object)

# %%
dataset['study_method'].unique()
# Out:
# array(['coaching', 'online videos', 'mixed', 'self-study', 'group study'],
#       dtype=object)

# %%
dataset['facility_rating'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
dataset['exam_difficulty'].unique()
# Out:
# array(['hard', 'moderate', 'easy'], dtype=object)

# %%
dataset.describe(include='object')
# Out:
#        gender course internet_access sleep_quality study_method  \
# count   20000  20000           20000         20000        20000
# unique      3      7               2             3            5
# top     other    bca             yes       average   self-study
# freq     6726   2902           16988          6694         4079
#
#        facility_rating exam_difficulty
# count            20000           20000
# unique               3               3
# top             medium        moderate
# freq              6760            9878

# %%
dataset
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 0               1   17    male  diploma         2.78              92.9
# 1               2   23   other      bca         3.37              64.8
# 2               3   22    male     b.sc         7.88              76.8
# 3               4   20   other  diploma         0.67              48.4
# 4               5   20  female  diploma         0.89              71.6
# ...           ...  ...     ...      ...          ...               ...
# 19995       19997   18   other      bba         6.50              71.3
# 19996       19998   18    male    b.com         3.71              41.6
# 19997       19999   19   other  diploma         7.88              68.2
# 19998       20000   19    male      bba         4.60              76.3
# 19999       20001   20    male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality   study_method  \
# ...

# %%
# Finding out which gender has the highestcount to take exam
max_gender = dataset['gender'].value_counts()
print(max_gender)
# Out:
# gender
# other     6726
# male      6695
# female    6579
# Name: count, dtype: int64

# %%
# Finding ouy which gender has the highestcount to take exam
max_gender = dataset['gender'].value_counts()
print(max_gender)
# Out:
# gender
# other     6726
# male      6695
# female    6579
# Name: count, dtype: int64

# %%
# Finding out how many of the student had internet access.
max_internet = dataset['internet_access'].value_counts()
print(max_internet)
# Out:
# internet_access
# yes    16988
# no      3012
# Name: count, dtype: int64

# %%
# Finding the highest sleep quality among the student
max_sleep = dataset['sleep_quality'].value_counts()
print(max_sleep)
# Out:
# sleep_quality
# average    6694
# poor       6687
# good       6619
# Name: count, dtype: int64

# %%
# Finding out which studying method is mostly used by the stuydents.
max_study = dataset['study_method'].value_counts()
print(max_study)
# Out:
# study_method
# self-study       4079
# online videos    4069
# coaching         4036
# group study      3922
# mixed            3894
# Name: count, dtype: int64

# %%
# Fining out the highest facility rating 
max_facility = dataset['facility_rating'].value_counts()
print(max_facility)
# Out:
# facility_rating
# medium    6760
# low       6638
# high      6602
# Name: count, dtype: int64

# %%
# Finding the highest exam difficulty that was taken by the students
max_exam = dataset['exam_difficulty'].value_counts()
print(max_exam)
# Out:
# exam_difficulty
# moderate    9878
# easy        6141
# hard        3981
# Name: count, dtype: int64

# %%
dataset
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 0               1   17    male  diploma         2.78              92.9
# 1               2   23   other      bca         3.37              64.8
# 2               3   22    male     b.sc         7.88              76.8
# 3               4   20   other  diploma         0.67              48.4
# 4               5   20  female  diploma         0.89              71.6
# ...           ...  ...     ...      ...          ...               ...
# 19995       19997   18   other      bba         6.50              71.3
# 19996       19998   18    male    b.com         3.71              41.6
# 19997       19999   19   other  diploma         7.88              68.2
# 19998       20000   19    male      bba         4.60              76.3
# 19999       20001   20    male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality   study_method  \
# ...

# %%
# Average hour spent by each gender on study
average_study_hour = dataset.groupby('gender')['study_hours'].mean().sort_values(ascending=False)
print(average_study_hour)
# Out:
# gender
# male      4.022018
# other     4.004741
# female    3.995861
# Name: study_hours, dtype: float64

# %%
# Average class attendance of each gender
average_class_attendance = dataset.groupby('gender')['class_attendance'].mean().sort_values(ascending=False)
print(average_class_attendance)
# Out:
# gender
# female    70.147500
# other     70.055412
# male      69.851262
# Name: class_attendance, dtype: float64

# %%
# Average sleep hour of each gender
average_sleep_hour = dataset.groupby('gender')['sleep_hours'].mean().sort_values(ascending=False)
print(average_sleep_hour)
# Out:
# gender
# female    7.033121
# other     7.010497
# male      6.982479
# Name: sleep_hours, dtype: float64

# %%
# checking the sleep quality of all gender based on average,good and poor
sleep_quality = dataset.groupby(['gender', 'sleep_quality']).size()
print(sleep_quality)
# Out:
# gender  sleep_quality
# female  average          2157
#         good             2278
#         poor             2144
# male    average          2265
#         good             2152
#         poor             2278
# other   average          2272
#         good             2189
#         poor             2265
# dtype: int64

# %%
# checking the prefered study method of each gender
study_method = dataset.groupby(['gender', 'study_method']).size()
print(study_method)
# Out:
# gender  study_method
# female  coaching         1350
#         group study      1273
#         mixed            1284
#         online videos    1323
#         self-study       1349
# male    coaching         1315
#         group study      1282
#         mixed            1324
#         online videos    1386
#         self-study       1388
# other   coaching         1371
#         group study      1367
#         mixed            1286
#         online videos    1360
#         self-study       1342
# dtype: int64

# %%
# checking the exam difficulty taken by each gender
exam_difficulty = dataset.groupby(['gender', 'exam_difficulty']).size()
print(exam_difficulty)
# Out:
# gender  exam_difficulty
# female  easy               2025
#         hard               1294
#         moderate           3260
# male    easy               2073
#         hard               1305
#         moderate           3317
# other   easy               2043
#         hard               1382
#         moderate           3301
# dtype: int64

# %%
# Average exam score of each gender
average_score = dataset.groupby('gender')['exam_score'].mean().sort_values(ascending=False)
print(average_score)
# Out:
# gender
# female    62.582145
# other     62.561023
# male      62.397480
# Name: exam_score, dtype: float64

# %%
# Average age 
average_age = dataset.groupby('gender')['age'].mean().sort_values(ascending=False)
print(average_age)
# Out:
# gender
# female    20.480164
# other     20.473684
# male      20.466169
# Name: age, dtype: float64

# %% [markdown]
# DATA VISUALIZATION

# %%
dataset
# Out:
#        student_id  age  gender   course  study_hours  class_attendance  \
# 0               1   17    male  diploma         2.78              92.9
# 1               2   23   other      bca         3.37              64.8
# 2               3   22    male     b.sc         7.88              76.8
# 3               4   20   other  diploma         0.67              48.4
# 4               5   20  female  diploma         0.89              71.6
# ...           ...  ...     ...      ...          ...               ...
# 19995       19997   18   other      bba         6.50              71.3
# 19996       19998   18    male    b.com         3.71              41.6
# 19997       19999   19   other  diploma         7.88              68.2
# 19998       20000   19    male      bba         4.60              76.3
# 19999       20001   20    male     b.sc         7.50              47.9
#
#       internet_access  sleep_hours sleep_quality   study_method  \
# ...

# %%
# Showing how exam scores are distributed and where most students score.
plt.figure()
sns.histplot(dataset['exam_score'], bins=10, kde=True)
plt.title("Distribution of Exam Scores")
plt.xlabel("Exam Score")
plt.ylabel("Count")
plt.show()

# %%
plt.figure()
sns.scatterplot(x='study_hours', y='exam_score', data=dataset)
plt.title("Hours Studied vs Exam Score")
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.show()

# %% [markdown]
# Clear positive trend = more study hours gets you better scores.

# %%
plt.figure()
sns.boxplot(x='gender', y='exam_score', data=dataset)
plt.title("Exam Score Distribution by Gender")
plt.xlabel("Gender")
plt.ylabel("Exam Score")
plt.show()
# Compares score spread and outliers between groups.

# %%
plt.figure()
sns.countplot(x='gender', data=dataset)
plt.title("Count of Students by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
# Showing data balance between categories.

# %%
plt.figure()
corr = dataset.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
